# %%
# import the dependencies 
import pandas as pd 
import matplotlib.pyplot as plt 
import numpy as np 
from citipy import citipy
import requests
import time 
from datetime import datetime

from datetime import datetime
from config import weather_api_key

# %%
# create a set of random latitude and longtitude combinations 
lats = np.random.uniform( low = -90.000, high = 90.000, size = 2000)
lngs = np.random.uniform( low = -180.000, high = 180.000, size = 2000)
lat_lngs = zip(lats,lngs)

lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
cities = [] 

for coordinate in coordinates: 
    city = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    
    if city not in cities: 
        cities.append(city)
        
len(cities)
# Out:
# 617

# %%
url = "https://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
city_url = url + "&q=" + city.replace(" ", "+")

# %%
city_weather = requests.get(city_url).json()
city_weather
# Out:
# {'coord': {'lon': 111.9767, 'lat': 43.6475},
#  'weather': [{'id': 800,
#    'main': 'Clear',
#    'description': 'clear sky',
#    'icon': '01n'}],
#  'base': 'stations',
#  'main': {'temp': 40.57,
#   'feels_like': 32.25,
#   'temp_min': 40.57,
#   'temp_max': 40.57,
#   'pressure': 1023,
#   'humidity': 46,
#   'sea_level': 1023,
#   'grnd_level': 910},
#  'visibility': 10000,
#  'wind': {'speed': 16.04, 'deg': 34, 'gust': 27.81},
#  'clouds': {'all': 1},
#  'dt': 1649091903,
#  'sys': {'country': 'CN', 'sunrise': 1649110039, 'sunset': 1649156528},
#  'timezone': 28800,
#  'id': 2037485,
#  'name': 'Erenhot',
#  'cod': 200}

# %%
city_weather_data = [] 

#print the beginning of the logging 
print("Beginning Data Retrieval     ")
print("-----------------------------")

record_count = 1 
set_count = 1 

# loop through all the cities in our list 
for i, city in enumerate(cities): 
    # group cities in sets of 50 for logging purposes 
    if (i % 50 == 0 and i >= 50 ): 
        set_count += 1 
        record_count = 1 
    
    # create endpoint URL with each city 
    city_url = url + "&q=" + city.replace(" ", "+")
    
    #Log the URL, record, and set numbers and the city 
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    #add 1 to the record count 
    record_count +=1 

    try: 
        
        #parse out the needed data 
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_weather_description = city_weather['weather'][0]['description']
        
        
        #append the city information into city_data list 
        city_weather_data.append({"City": city.title(),
                         "Lat": city_lat,
                         "Lng": city_lng,
                         "Max_Temp": city_max_temp,
                         "Humidity":city_humidity,
                         "Cloudiness": city_clouds,
                         "Wind Speed": city_wind,
                         "Weather description":city_weather_description}
                                )
    except: 
        print('City not found. Skipping....')
        pass

#Indicate that Data Loading is complete. 
print("-----------------------------")
print("Data Retreival Complete")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kirakira
# Processing Record 2 of Set 1 | qaanaaq
# Processing Record 3 of Set 1 | kudahuvadhoo
# Processing Record 4 of Set 1 | kapaa
# Processing Record 5 of Set 1 | albany
# Processing Record 6 of Set 1 | ushuaia
# Processing Record 7 of Set 1 | airai
# Processing Record 8 of Set 1 | jamestown
# Processing Record 9 of Set 1 | kruisfontein
# Processing Record 10 of Set 1 | east london
# Processing Record 11 of Set 1 | yellowknife
# Processing Record 12 of Set 1 | winslow
# Processing Record 13 of Set 1 | dingle
# Processing Record 14 of Set 1 | galeana
# Processing Record 15 of Set 1 | busselton
# Processing Record 16 of Set 1 | hilo
# Processing Record 17 of Set 1 | bargal
# Processing Record 18 of Set 1 | saint anthony
# Processing Record 19 of Set 1 | pavlovsk
# Processing Record 20 of Set 1 | rikitea
# Processing Record 21 of Set 1 | carnarvon
# Processing Record 22 of Set 1 | irbit
# Processing Record 23 of Set 1 | anisoc
# Processing Record 24 of Set 1 | alexandria
# Processing Record 25 of Set 1 | komsomolskiy
# Processing Record 26 of Set 1 | tipperary
# Processing Record 27 of Set 1 | cukai
# Processing Record 28 of Set 1 | butaritari
# Processing Record 29 of Set 1 | norman wells
# Processing Record 30 of Set 1 | vagamo
# Processing Record 31 of Set 1 | jining
# Processing Record 32 of Set 1 | devonport
# Processing Record 33 of Set 1 | taolanaro
# Processing Record 34 of Set 1 | hobart
# Processing Record 35 of Set 1 | guarapari
# Processing Record 36 of Set 1 | santa isabel do rio negro
# Processing Record 37 of Set 1 | voznesenye
# Processing Record 38 of Set 1 | tabou
# Processing Record 39 of Set 1 | vaini
# Processing Record 40 of Set 1 | aklavik
# Processing Record 41 of Set 1 | port blair
# Processing Record 42 of Set 1 | port elizabeth
# Processing Record 43 of Set 1 | pisco
# Processing Record 44 of Set 1 | hobyo
# Processing Record 45 of Set 1 | saleaula
# Processing Record 46 of Set 1 | acobamba
# Processing Record 47 of Set 1 | baykit
# Processing Record 48 of Set 1 | pacific grove
# Processing Record 49 of Set 1 | castro
# Processing Record 50 of Set 1 | mataura
# Processing Record 1 of Set 2 | berdigestyakh
# Processing Record 2 of Set 2 | chipinge
# Processing Record 3 of Set 2 | sulecin
# Processing Record 4 of Set 2 | illoqqortoormiut
# Processing Record 5 of Set 2 | barentsburg
# Processing Record 6 of Set 2 | puerto ayora
# Processing Record 7 of Set 2 | waipawa
# Processing Record 8 of Set 2 | ponta do sol
# Processing Record 9 of Set 2 | hermanus
# Processing Record 10 of Set 2 | griffith
# Processing Record 11 of Set 2 | khatanga
# Processing Record 12 of Set 2 | gap
# Processing Record 13 of Set 2 | mahibadhoo
# Processing Record 14 of Set 2 | talnakh
# Processing Record 15 of Set 2 | san luis
# Processing Record 16 of Set 2 | ancud
# Processing Record 17 of Set 2 | new norfolk
# Processing Record 18 of Set 2 | huanren
# Processing Record 19 of Set 2 | punta arenas
# Processing Record 20 of Set 2 | georgetown
# Processing Record 21 of Set 2 | mount airy
# Processing Record 22 of Set 2 | polovinnoye
# Processing Record 23 of Set 2 | tuatapere
# Processing Record 24 of Set 2 | lasa
# Processing Record 25 of Set 2 | sentyabrskiy
# Processing Record 26 of Set 2 | atuona
# Processing Record 27 of Set 2 | bushehr
# Processing Record 28 of Set 2 | carutapera
# Processing Record 29 of Set 2 | ixtapa
# Processing Record 30 of Set 2 | cessnock
# Processing Record 31 of Set 2 | witu
# Processing Record 32 of Set 2 | inhambane
# Processing Record 33 of Set 2 | luderitz
# Processing Record 34 of Set 2 | cape town
# Processing Record 35 of Set 2 | chuy
# Processing Record 36 of Set 2 | chokurdakh
# Processing Record 37 of Set 2 | kourou
# Processing Record 38 of Set 2 | okhotsk
# Processing Record 39 of Set 2 | khor
# Processing Record 40 of Set 2 | provideniya
# Processing Record 41 of Set 2 | namatanai
# Processing Record 42 of Set 2 | nouadhibou
# Processing Record 43 of Set 2 | nizwa
# Processing Record 44 of Set 2 | udachnyy
# Processing Record 45 of Set 2 | te anau
# Processing Record 46 of Set 2 | mahebourg
# Processing Record 47 of Set 2 | longyearbyen
# Processing Record 48 of Set 2 | tuktoyaktuk
# Processing Record 49 of Set 2 | bredasdorp
# Processing Record 50 of Set 2 | bethel
# Processing Record 1 of Set 3 | arraial do cabo
# Processing Record 2 of Set 3 | port alfred
# Processing Record 3 of Set 3 | flin flon
# Processing Record 4 of Set 3 | saint-augustin
# Processing Record 5 of Set 3 | barrow
# Processing Record 6 of Set 3 | saskylakh
# Processing Record 7 of Set 3 | miri
# Processing Record 8 of Set 3 | saint-philippe
# Processing Record 9 of Set 3 | wuchang
# Processing Record 10 of Set 3 | laguna
# Processing Record 11 of Set 3 | husavik
# Processing Record 12 of Set 3 | saint george
# Processing Record 13 of Set 3 | faanui
# Processing Record 14 of Set 3 | cherskiy
# Processing Record 15 of Set 3 | bredy
# Processing Record 16 of Set 3 | walvis bay
# Processing Record 17 of Set 3 | phek
# Processing Record 18 of Set 3 | ambilobe
# Processing Record 19 of Set 3 | lingolsheim
# Processing Record 20 of Set 3 | adelaide
# Processing Record 21 of Set 3 | benguela
# Processing Record 22 of Set 3 | tucurui
# Processing Record 23 of Set 3 | san cristobal
# Processing Record 24 of Set 3 | amahai
# Processing Record 25 of Set 3 | ajdabiya
# Processing Record 26 of Set 3 | la rioja
# Processing Record 27 of Set 3 | taltal
# Processing Record 28 of Set 3 | bilma
# Processing Record 29 of Set 3 | xai-xai
# Processing Record 30 of Set 3 | izhmorskiy
# Processing Record 31 of Set 3 | yulara
# Processing Record 32 of Set 3 | belushya guba
# Processing Record 33 of Set 3 | mayo
# Processing Record 34 of Set 3 | henties bay
# Processing Record 35 of Set 3 | iqaluit
# Processing Record 36 of Set 3 | anito
# Processing Record 37 of Set 3 | vaitupu
# Processing Record 38 of Set 3 | attawapiskat
# Processing Record 39 of Set 3 | bluff
# Processing Record 40 of Set 3 | bontang
# Processing Record 41 of Set 3 | padang
# Processing Record 42 of Set 3 | hasaki
# Processing Record 43 of Set 3 | luena
# Processing Record 44 of Set 3 | miranda
# Processing Record 45 of Set 3 | salinas
# Processing Record 46 of Set 3 | bambous virieux
# Processing Record 47 of Set 3 | izhevskoye
# Processing Record 48 of Set 3 | broken hill
# Processing Record 49 of Set 3 | cap malheureux
# Processing Record 50 of Set 3 | kodiak
# Processing Record 1 of Set 4 | whitehorse
# Processing Record 2 of Set 4 | rio claro
# Processing Record 3 of Set 4 | alofi
# Processing Record 4 of Set 4 | itarema
# Processing Record 5 of Set 4 | saldanha
# Processing Record 6 of Set 4 | hithadhoo
# Processing Record 7 of Set 4 | grand river south east
# Processing Record 8 of Set 4 | seguela
# Processing Record 9 of Set 4 | omsukchan
# Processing Record 10 of Set 4 | dikson
# Processing Record 11 of Set 4 | isangel
# Processing Record 12 of Set 4 | pevek
# Processing Record 13 of Set 4 | rocha
# Processing Record 14 of Set 4 | bellmead
# Processing Record 15 of Set 4 | sao mateus
# Processing Record 16 of Set 4 | lebu
# Processing Record 17 of Set 4 | bengkulu
# Processing Record 18 of Set 4 | kotelnich
# Processing Record 19 of Set 4 | esperance
# Processing Record 20 of Set 4 | avarua
# Processing Record 21 of Set 4 | mount gambier
# Processing Record 22 of Set 4 | kaitangata
# Processing Record 23 of Set 4 | male
# Processing Record 24 of Set 4 | constitucion
# Processing Record 25 of Set 4 | muana
# Processing Record 26 of Set 4 | sitka
# Processing Record 27 of Set 4 | korla
# Processing Record 28 of Set 4 | campbellton
# Processing Record 29 of Set 4 | nichinan
# Processing Record 30 of Set 4 | talara
# Processing Record 31 of Set 4 | krasnoselkup
# Processing Record 32 of Set 4 | nizhneyansk
# Processing Record 33 of Set 4 | rabo de peixe
# Processing Record 34 of Set 4 | ordynskoye
# Processing Record 35 of Set 4 | ulety
# Processing Record 36 of Set 4 | barbar
# Processing Record 37 of Set 4 | lavrentiya
# Processing Record 38 of Set 4 | cordoba
# Processing Record 39 of Set 4 | tazovskiy
# Processing Record 40 of Set 4 | hun
# Processing Record 41 of Set 4 | goure
# Processing Record 42 of Set 4 | ahuimanu
# Processing Record 43 of Set 4 | lorengau
# Processing Record 44 of Set 4 | umzimvubu
# Processing Record 45 of Set 4 | meylan
# Processing Record 46 of Set 4 | gravdal
# Processing Record 47 of Set 4 | north bend
# Processing Record 48 of Set 4 | shimoda
# Processing Record 49 of Set 4 | sterling
# Processing Record 50 of Set 4 | katsuura
# Processing Record 1 of Set 5 | hofn
# Processing Record 2 of Set 5 | gazanjyk
# Processing Record 3 of Set 5 | sibu
# Processing Record 4 of Set 5 | lebanon
# Processing Record 5 of Set 5 | el faiyum
# Processing Record 6 of Set 5 | torbay
# Processing Record 7 of Set 5 | rio gallegos
# Processing Record 8 of Set 5 | guerrero negro
# Processing Record 9 of Set 5 | avera
# Processing Record 10 of Set 5 | marsa matruh
# Processing Record 11 of Set 5 | narsaq
# Processing Record 12 of Set 5 | mehamn
# Processing Record 13 of Set 5 | pangascasan
# Processing Record 14 of Set 5 | maragogi
# Processing Record 15 of Set 5 | kieta
# Processing Record 16 of Set 5 | altay
# Processing Record 17 of Set 5 | saint-pierre
# Processing Record 18 of Set 5 | tasiilaq
# Processing Record 19 of Set 5 | skage
# Processing Record 20 of Set 5 | asilah
# Processing Record 21 of Set 5 | grand gaube
# Processing Record 22 of Set 5 | tsihombe
# Processing Record 23 of Set 5 | south yarmouth
# Processing Record 24 of Set 5 | tairua
# Processing Record 25 of Set 5 | leningradskiy
# Processing Record 26 of Set 5 | college
# Processing Record 27 of Set 5 | tobol
# Processing Record 28 of Set 5 | saint albans
# Processing Record 29 of Set 5 | la ronge
# Processing Record 30 of Set 5 | little current
# Processing Record 31 of Set 5 | cascais
# Processing Record 32 of Set 5 | outlook
# Processing Record 33 of Set 5 | lolua
# Processing Record 34 of Set 5 | upernavik
# Processing Record 35 of Set 5 | erzincan
# Processing Record 36 of Set 5 | thompson
# Processing Record 37 of Set 5 | ribeira grande
# Processing Record 38 of Set 5 | port shepstone
# Processing Record 39 of Set 5 | bursa
# Processing Record 40 of Set 5 | fort saint john
# Processing Record 41 of Set 5 | pirganj
# Processing Record 42 of Set 5 | capanema
# Processing Record 43 of Set 5 | hambantota
# Processing Record 44 of Set 5 | guilin
# Processing Record 45 of Set 5 | lagoa
# Processing Record 46 of Set 5 | dongsheng
# Processing Record 47 of Set 5 | shihezi
# Processing Record 48 of Set 5 | nanortalik
# Processing Record 49 of Set 5 | loikaw
# Processing Record 50 of Set 5 | srednekolymsk
# Processing Record 1 of Set 6 | orocue
# Processing Record 2 of Set 6 | clyde river
# Processing Record 3 of Set 6 | flinders
# Processing Record 4 of Set 6 | ilinskiy
# Processing Record 5 of Set 6 | bhera
# Processing Record 6 of Set 6 | san rafael
# Processing Record 7 of Set 6 | kloulklubed
# Processing Record 8 of Set 6 | vokhtoga
# Processing Record 9 of Set 6 | port hardy
# Processing Record 10 of Set 6 | boma
# Processing Record 11 of Set 6 | kasama
# Processing Record 12 of Set 6 | dianopolis
# Processing Record 13 of Set 6 | indianola
# Processing Record 14 of Set 6 | kamogawa
# Processing Record 15 of Set 6 | mys shmidta
# Processing Record 16 of Set 6 | el campo
# Processing Record 17 of Set 6 | kuytun
# Processing Record 18 of Set 6 | porto novo
# Processing Record 19 of Set 6 | pochutla
# Processing Record 20 of Set 6 | lompoc
# Processing Record 21 of Set 6 | ilulissat
# Processing Record 22 of Set 6 | nikolskoye
# Processing Record 23 of Set 6 | necochea
# Processing Record 24 of Set 6 | severo-kurilsk
# Processing Record 25 of Set 6 | shingu
# Processing Record 26 of Set 6 | bambanglipuro
# Processing Record 27 of Set 6 | batagay-alyta
# Processing Record 28 of Set 6 | labuhan
# Processing Record 29 of Set 6 | botwood
# Processing Record 30 of Set 6 | mar del plata
# Processing Record 31 of Set 6 | baracoa
# Processing Record 32 of Set 6 | freeport
# Processing Record 33 of Set 6 | dunedin
# Processing Record 34 of Set 6 | straumen
# Processing Record 35 of Set 6 | kuito
# Processing Record 36 of Set 6 | zlatoustovsk
# Processing Record 37 of Set 6 | axim
# Processing Record 38 of Set 6 | poum
# Processing Record 39 of Set 6 | cayenne
# Processing Record 40 of Set 6 | san diego de los banos
# Processing Record 41 of Set 6 | imbituba
# Processing Record 42 of Set 6 | san patricio
# Processing Record 43 of Set 6 | pontianak
# Processing Record 44 of Set 6 | verkh-suetka
# Processing Record 45 of Set 6 | bukachacha
# Processing Record 46 of Set 6 | kathu
# Processing Record 47 of Set 6 | fuyang
# Processing Record 48 of Set 6 | ayorou
# Processing Record 49 of Set 6 | aswan
# Processing Record 50 of Set 6 | alindao
# Processing Record 1 of Set 7 | mashhad
# Processing Record 2 of Set 7 | catuday
# Processing Record 3 of Set 7 | sao felix do xingu
# Processing Record 4 of Set 7 | along
# Processing Record 5 of Set 7 | puerto carreno
# Processing Record 6 of Set 7 | oktyabrskiy
# Processing Record 7 of Set 7 | kurmanayevka
# Processing Record 8 of Set 7 | san policarpo
# Processing Record 9 of Set 7 | vinukonda
# Processing Record 10 of Set 7 | tattayyangarpettai
# Processing Record 11 of Set 7 | coquimbo
# Processing Record 12 of Set 7 | verkh-usugli
# Processing Record 13 of Set 7 | kahului
# Processing Record 14 of Set 7 | robertsport
# Processing Record 15 of Set 7 | impfondo
# Processing Record 16 of Set 7 | jalu
# Processing Record 17 of Set 7 | quang ngai
# Processing Record 18 of Set 7 | naryan-mar
# Processing Record 19 of Set 7 | marienburg
# Processing Record 20 of Set 7 | kasamwa
# Processing Record 21 of Set 7 | karratha
# Processing Record 22 of Set 7 | victoria
# Processing Record 23 of Set 7 | syracuse
# Processing Record 24 of Set 7 | svobodnyy
# Processing Record 25 of Set 7 | rundu
# Processing Record 26 of Set 7 | isabela
# Processing Record 27 of Set 7 | buraydah
# Processing Record 28 of Set 7 | geraldton
# Processing Record 29 of Set 7 | aleksandrov gay
# Processing Record 30 of Set 7 | zyryanka
# Processing Record 31 of Set 7 | san jeronimo
# Processing Record 32 of Set 7 | verkhoyansk
# Processing Record 33 of Set 7 | nicoya
# Processing Record 34 of Set 7 | vitimskiy
# Processing Record 35 of Set 7 | ko samui
# Processing Record 36 of Set 7 | kavaratti
# Processing Record 37 of Set 7 | salalah
# Processing Record 38 of Set 7 | itaituba
# Processing Record 39 of Set 7 | bodden town
# Processing Record 40 of Set 7 | marcona
# Processing Record 41 of Set 7 | lipin bor
# Processing Record 42 of Set 7 | nadvoitsy
# Processing Record 43 of Set 7 | lata
# Processing Record 44 of Set 7 | jinchang
# Processing Record 45 of Set 7 | naushki
# Processing Record 46 of Set 7 | jacareacanga
# Processing Record 47 of Set 7 | kuche
# Processing Record 48 of Set 7 | marzuq
# Processing Record 49 of Set 7 | marawi
# Processing Record 50 of Set 7 | leshukonskoye
# Processing Record 1 of Set 8 | sao joao da barra
# Processing Record 2 of Set 8 | touros
# Processing Record 3 of Set 8 | zaranj
# Processing Record 4 of Set 8 | half moon bay
# Processing Record 5 of Set 8 | nishihara
# Processing Record 6 of Set 8 | sosnovo-ozerskoye
# Processing Record 7 of Set 8 | tiznit
# Processing Record 8 of Set 8 | abalak
# Processing Record 9 of Set 8 | filadelfia
# Processing Record 10 of Set 8 | umm lajj
# Processing Record 11 of Set 8 | havelock
# Processing Record 12 of Set 8 | san vicente
# Processing Record 13 of Set 8 | belaya gora
# Processing Record 14 of Set 8 | ust-tsilma
# Processing Record 15 of Set 8 | qaqortoq
# Processing Record 16 of Set 8 | galgani
# Processing Record 17 of Set 8 | aksu
# Processing Record 18 of Set 8 | thinadhoo
# Processing Record 19 of Set 8 | cidreira
# Processing Record 20 of Set 8 | kavieng
# Processing Record 21 of Set 8 | teya
# Processing Record 22 of Set 8 | elliot lake
# Processing Record 23 of Set 8 | stolin
# Processing Record 24 of Set 8 | lima
# Processing Record 25 of Set 8 | san pedro
# Processing Record 26 of Set 8 | vostok
# Processing Record 27 of Set 8 | coihaique
# Processing Record 28 of Set 8 | khromtau
# Processing Record 29 of Set 8 | beringovskiy
# Processing Record 30 of Set 8 | xining
# Processing Record 31 of Set 8 | alyangula
# Processing Record 32 of Set 8 | bolungarvik
# Processing Record 33 of Set 8 | ovre ardal
# Processing Record 34 of Set 8 | meulaboh
# Processing Record 35 of Set 8 | beroroha
# Processing Record 36 of Set 8 | trinidad
# Processing Record 37 of Set 8 | moshenskoye
# Processing Record 38 of Set 8 | fort nelson
# Processing Record 39 of Set 8 | challapata
# Processing Record 40 of Set 8 | sipe sipe
# Processing Record 41 of Set 8 | bucarasica
# Processing Record 42 of Set 8 | tomatlan
# Processing Record 43 of Set 8 | tiksi
# Processing Record 44 of Set 8 | strezhevoy
# Processing Record 45 of Set 8 | dire dawa
# Processing Record 46 of Set 8 | khorixas
# Processing Record 47 of Set 8 | ereymentau
# Processing Record 48 of Set 8 | nelson bay
# Processing Record 49 of Set 8 | paradwip
# Processing Record 50 of Set 8 | port lincoln
# Processing Record 1 of Set 9 | navapur
# Processing Record 2 of Set 9 | quzhou
# Processing Record 3 of Set 9 | madingou
# Processing Record 4 of Set 9 | toora-khem
# Processing Record 5 of Set 9 | san quintin
# Processing Record 6 of Set 9 | horsham
# Processing Record 7 of Set 9 | souillac
# Processing Record 8 of Set 9 | chapais
# Processing Record 9 of Set 9 | puerto baquerizo moreno
# Processing Record 10 of Set 9 | naze
# Processing Record 11 of Set 9 | todos santos
# Processing Record 12 of Set 9 | majene
# Processing Record 13 of Set 9 | saint-louis
# Processing Record 14 of Set 9 | paciran
# Processing Record 15 of Set 9 | bathsheba
# Processing Record 16 of Set 9 | tabas
# Processing Record 17 of Set 9 | sechura
# Processing Record 18 of Set 9 | ahipara
# Processing Record 19 of Set 9 | launceston
# Processing Record 20 of Set 9 | tura
# Processing Record 21 of Set 9 | vanimo
# Processing Record 22 of Set 9 | conde
# Processing Record 23 of Set 9 | gebre guracha
# Processing Record 24 of Set 9 | warwick
# Processing Record 25 of Set 9 | stornoway
# Processing Record 26 of Set 9 | hami
# Processing Record 27 of Set 9 | fortuna
# Processing Record 28 of Set 9 | arzgir
# Processing Record 29 of Set 9 | barabai
# Processing Record 30 of Set 9 | cabras
# Processing Record 31 of Set 9 | pangnirtung
# Processing Record 32 of Set 9 | olafsvik
# Processing Record 33 of Set 9 | amuntai
# Processing Record 34 of Set 9 | eyl
# Processing Record 35 of Set 9 | vardo
# Processing Record 36 of Set 9 | chase
# Processing Record 37 of Set 9 | kefamenanu
# Processing Record 38 of Set 9 | machico
# Processing Record 39 of Set 9 | comodoro rivadavia
# Processing Record 40 of Set 9 | sabzevar
# Processing Record 41 of Set 9 | wahpeton
# Processing Record 42 of Set 9 | mareeba
# Processing Record 43 of Set 9 | hamilton
# Processing Record 44 of Set 9 | sur
# Processing Record 45 of Set 9 | murray bridge
# Processing Record 46 of Set 9 | gizo
# Processing Record 47 of Set 9 | kabompo
# Processing Record 48 of Set 9 | fare
# Processing Record 49 of Set 9 | richards bay
# Processing Record 50 of Set 9 | mizan teferi
# Processing Record 1 of Set 10 | bilibino
# Processing Record 2 of Set 10 | urengoy
# Processing Record 3 of Set 10 | westport
# Processing Record 4 of Set 10 | namwala
# Processing Record 5 of Set 10 | sal rei
# Processing Record 6 of Set 10 | nhulunbuy
# Processing Record 7 of Set 10 | luganville
# Processing Record 8 of Set 10 | nador
# Processing Record 9 of Set 10 | asayita
# Processing Record 10 of Set 10 | bara
# Processing Record 11 of Set 10 | batticaloa
# Processing Record 12 of Set 10 | roald
# Processing Record 13 of Set 10 | sakakah
# Processing Record 14 of Set 10 | codrington
# Processing Record 15 of Set 10 | rawson
# Processing Record 16 of Set 10 | pitimbu
# Processing Record 17 of Set 10 | bulalacao
# Processing Record 18 of Set 10 | teahupoo
# Processing Record 19 of Set 10 | kadoma
# Processing Record 20 of Set 10 | ondorhaan
# Processing Record 21 of Set 10 | libertad
# Processing Record 22 of Set 10 | san jose de guanipa
# Processing Record 23 of Set 10 | romanovskaya
# Processing Record 24 of Set 10 | orlik
# Processing Record 25 of Set 10 | sola
# Processing Record 26 of Set 10 | winnemucca
# Processing Record 27 of Set 10 | quelimane
# Processing Record 28 of Set 10 | colon
# Processing Record 29 of Set 10 | kaduqli
# Processing Record 30 of Set 10 | aleksandrovskoye
# Processing Record 31 of Set 10 | palana
# Processing Record 32 of Set 10 | sembe
# Processing Record 33 of Set 10 | twentynine palms
# Processing Record 34 of Set 10 | riyadh
# Processing Record 35 of Set 10 | margate
# Processing Record 36 of Set 10 | kupang
# Processing Record 37 of Set 10 | chumikan
# Processing Record 38 of Set 10 | ketchikan
# Processing Record 39 of Set 10 | tendukheda
# Processing Record 40 of Set 10 | jiuquan
# Processing Record 41 of Set 10 | cuamba
# Processing Record 42 of Set 10 | itaqui
# Processing Record 43 of Set 10 | zeya
# Processing Record 44 of Set 10 | tigre
# Processing Record 45 of Set 10 | tumannyy
# Processing Record 46 of Set 10 | jizan
# Processing Record 47 of Set 10 | sisimiut
# Processing Record 48 of Set 10 | port macquarie
# Processing Record 49 of Set 10 | mitchell
# Processing Record 50 of Set 10 | tondano
# Processing Record 1 of Set 11 | kutum
# Processing Record 2 of Set 11 | cabedelo
# Processing Record 3 of Set 11 | yuli
# Processing Record 4 of Set 11 | faya
# Processing Record 5 of Set 11 | ivanivka
# Processing Record 6 of Set 11 | poro
# Processing Record 7 of Set 11 | nanakuli
# Processing Record 8 of Set 11 | kondoa
# Processing Record 9 of Set 11 | arawa
# Processing Record 10 of Set 11 | la libertad
# Processing Record 11 of Set 11 | sibolga
# Processing Record 12 of Set 11 | kuryk
# Processing Record 13 of Set 11 | tirlyanskiy
# Processing Record 14 of Set 11 | grindavik
# Processing Record 15 of Set 11 | baiyin
# Processing Record 16 of Set 11 | fandriana
# Processing Record 17 of Set 11 | susanville
# Processing Record 18 of Set 11 | acapulco
# Processing Record 19 of Set 11 | hay river
# Processing Record 20 of Set 11 | yarmouth
# Processing Record 21 of Set 11 | penzance
# Processing Record 22 of Set 11 | nkowakowa
# Processing Record 23 of Set 11 | kenai
# Processing Record 24 of Set 11 | aykhal
# Processing Record 25 of Set 11 | gigmoto
# Processing Record 26 of Set 11 | sept-iles
# Processing Record 27 of Set 11 | kihei
# Processing Record 28 of Set 11 | ust-kamchatsk
# Processing Record 29 of Set 11 | berlevag
# Processing Record 30 of Set 11 | amapa
# Processing Record 31 of Set 11 | bac lieu
# Processing Record 32 of Set 11 | nagornyy
# Processing Record 33 of Set 11 | urumqi
# Processing Record 34 of Set 11 | virginia beach
# Processing Record 35 of Set 11 | mount isa
# Processing Record 36 of Set 11 | takoradi
# Processing Record 37 of Set 11 | alice springs
# Processing Record 38 of Set 11 | kayes
# Processing Record 39 of Set 11 | cadereyta
# Processing Record 40 of Set 11 | falealupo
# Processing Record 41 of Set 11 | klaksvik
# Processing Record 42 of Set 11 | pekan
# Processing Record 43 of Set 11 | turayf
# Processing Record 44 of Set 11 | sumbe
# Processing Record 45 of Set 11 | portland
# Processing Record 46 of Set 11 | knyaze-volkonskoye
# Processing Record 47 of Set 11 | kempele
# Processing Record 48 of Set 11 | kazalinsk
# Processing Record 49 of Set 11 | dharchula
# Processing Record 50 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 1 of Set 12 | quatre cocos
# Processing Record 2 of Set 12 | machaneng
# Processing Record 3 of Set 12 | natal
# Processing Record 4 of Set 12 | caravelas
# Processing Record 5 of Set 12 | tunduru
# Processing Record 6 of Set 12 | mitu
# Processing Record 7 of Set 12 | selenginsk
# Processing Record 8 of Set 12 | hukuntsi
# Processing Record 9 of Set 12 | tessalit
# Processing Record 10 of Set 12 | cilegon
# Processing Record 11 of Set 12 | coruripe
# Processing Record 12 of Set 12 | pathein
# Processing Record 13 of Set 12 | belyy yar
# Processing Record 14 of Set 12 | gat
# Processing Record 15 of Set 12 | edgewater
# Processing Record 16 of Set 12 | antofagasta
# Processing Record 17 of Set 12 | guane
# Processing Record 18 of Set 12 | skalistyy
# Processing Record 19 of Set 12 | mushie
# Processing Record 20 of Set 12 | ossora
# Processing Record 21 of Set 12 | egvekinot
# Processing Record 22 of Set 12 | tigzirt
# Processing Record 23 of Set 12 | anloga
# Processing Record 24 of Set 12 | ambon
# Processing Record 25 of Set 12 | smithers
# Processing Record 26 of Set 12 | wulanhaote
# Processing Record 27 of Set 12 | tongling
# Processing Record 28 of Set 12 | catalina
# Processing Record 29 of Set 12 | saint combs
# Processing Record 30 of Set 12 | ginda
# Processing Record 31 of Set 12 | matsanga
# Processing Record 32 of Set 12 | mazagao
# Processing Record 33 of Set 12 | itatskiy
# Processing Record 34 of Set 12 | bubaque
# Processing Record 35 of Set 12 | makurdi
# Processing Record 36 of Set 12 | lokken verk
# Processing Record 37 of Set 12 | haines junction
# Processing Record 38 of Set 12 | duku
# Processing Record 39 of Set 12 | lhokseumawe
# Processing Record 40 of Set 12 | mentok
# Processing Record 41 of Set 12 | achisay
# Processing Record 42 of Set 12 | fianarantsoa
# Processing Record 43 of Set 12 | joshimath
# Processing Record 44 of Set 12 | mugur-aksy
# Processing Record 45 of Set 12 | muzhi
# Processing Record 46 of Set 12 | port-gentil
# Processing Record 47 of Set 12 | urdzhar
# Processing Record 48 of Set 12 | loandjili
# Processing Record 49 of Set 12 | konin
# Processing Record 50 of Set 12 | ostrovnoy
# Processing Record 1 of Set 13 | santa vitoria
# Processing Record 2 of Set 13 | fujin
# Processing Record 3 of Set 13 | saint-joseph
# Processing Record 4 of Set 13 | manakara
# Processing Record 5 of Set 13 | birao
# Processing Record 6 of Set 13 | irbeyskoye
# Processing Record 7 of Set 13 | vila velha
# Processing Record 8 of Set 13 | jujuy
# Processing Record 9 of Set 13 | hihifo
# Processing Record 10 of Set 13 | cananeia
# Processing Record 11 of Set 13 | sao filipe
# Processing Record 12 of Set 13 | hinton
# Processing Record 13 of Set 13 | kyren
# Processing Record 14 of Set 13 | yerofey pavlovich
# Processing Record 15 of Set 13 | howard
# Processing Record 16 of Set 13 | horasan
# Processing Record 17 of Set 13 | erenhot
# -----------------------------
# Data Retreival Complete
# -----------------------------

# %%
# convert the array of dictionaries to a Pandas DataFrame 
city_weather_data_df = pd.DataFrame(city_weather_data)
city_weather_data_df.head(10)
# Out:
#            City      Lat       Lng  Max_Temp  Humidity  Cloudiness  \
# 0      Kirakira  43.6475  111.9767     40.57        46           1
# 1       Qaanaaq  43.6475  111.9767     40.57        46           1
# 2  Kudahuvadhoo  43.6475  111.9767     40.57        46           1
# 3         Kapaa  43.6475  111.9767     40.57        46           1
# 4        Albany  43.6475  111.9767     40.57        46           1
# 5       Ushuaia  43.6475  111.9767     40.57        46           1
# 6         Airai  43.6475  111.9767     40.57        46           1
# 7     Jamestown  43.6475  111.9767     40.57        46           1
# 8  Kruisfontein  43.6475  111.9767     40.57        46           1
# 9   East London  43.6475  111.9767     40.57        46           1
#
#    Wind Speed Weather description
# 0       16.04           clear sky
# 1       16.04           clear sky
# 2       16.04           clear sky
# 3       16.04           clear sky
# 4       16.04           clear sky
# 5       16.04           clear sky
# 6       16.04           clear sky
# 7       16.04           clear sky
# 8       16.04           clear sky
# 9       16.04           clear sky

# %%
output_data_file = "WeatherPy_Database.csv"
city_data_weather_df.to_csv(output_data_file, index_label="City ID")
